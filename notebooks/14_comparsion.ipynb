# %% [markdown]
# # Machine Learning Models Comparison
#
# This notebook compares the performance of various machine learning models trained for sentiment analysis on Amazon reviews.
#
# Models compared:
# - Logistic Regression
# - Naive Bayes
# - Support Vector Machine
# - K-Nearest Neighbors
# - Decision Trees
# - Random Forest
# - Stochastic Gradient Descent
# - XGBoost
# - LightGBM
#
# Metrics compared: Training Time (hyperparameter search time), Test Accuracy, F1-Score, and other aspects.

# %% [markdown]
# ## Comparison Table
#
# | Model | Training Time (s) | Test Accuracy | F1-Score | Hyperparameter Tuning | Notes |
# |-------|-------------------|---------------|----------|----------------------|-------|
# | Logistic Regression | 588.67 | 0.8898 | N/A | RandomizedSearchCV (5-fold, 50 iters) | Linear model, C, solver |
# | Naive Bayes | 16.78 | 0.8683 | N/A | RandomizedSearchCV (5-fold, 60 iters) | Probabilistic, alpha |
# | Support Vector Machine | N/A | 0.8891 | N/A | GridSearchCV (3-fold) | LinearSVC, C, loss |
# | K-Nearest Neighbors | 414.54 | 0.7716 | N/A | RandomizedSearchCV (3-fold, 20 iters) | Brute-force, k, metric |
# | Decision Trees | 21.12 | 0.7398 | 0.74 | GridSearchCV (3-fold) | Depth-controlled, max_depth |
# | Random Forest | N/A | 0.8533 | 0.8531 | RandomizedSearchCV (3-fold, 50 iters) | Ensemble, n_estimators |
# | Stochastic Gradient Descent | N/A | 0.8903 | 0.8902 | GridSearchCV (3-fold) | Fast linear, loss, penalty |
# | XGBoost | 1713.93 | 0.8525 | 0.8545 | RandomizedSearchCV (3-fold, 20 iters) | Gradient boosting, n_estimators |
# | LightGBM | 736.70 | 0.8612 | 0.8627 | RandomizedSearchCV (3-fold, 20 iters) | Leaf-wise, num_leaves |

# %% [markdown]
# ## Analysis
#
# - **Training Time**: XGBoost has the longest training time (1713.93 s), followed by LightGBM (736.70 s). Naive Bayes is the fastest (16.78 s).
# - **Accuracy**: SGD and Logistic Regression have the highest accuracy (~0.89), SVM similar. KNN has the lowest (0.77).
# - **F1-Score**: LightGBM has the highest F1 (0.8627), followed by SGD (0.8902).
# - **Other Aspects**: Tree-based models like Random Forest and boosting models perform well but take longer. Linear models are fast and accurate for this task.
